# %% [markdown]
# # Is the Number a Prime? (with a twist)

# %% [markdown]
# Write a function that takes a number and returns True if it's a prime; False otherwise. The number can be 2^64-1 (2 to the power of 63, not XOR).   With the standard technique it would be O(2^64-1), which is much too large for the 10 second time limit imposed by Edabit.
#
# Sieve of Eratosthenes
#
# ![image.png](attachment:4626d35c-43e2-4560-ac0c-1df175f6d2c2.png)
# Examples
# prime(7) ➞ True
#
# prime(56963) ➞ True
#
# prime(5151512515524) ➞ False
# Notes
# A "prime" number is a number that can only be divided by itself and 1 (upon division the result is a whole number).

# %% [markdown]
# # Solution

# %%
def prime(x):
    i=2
    while i**2<=x:
        if x%i==0:
            return False
        i+=1 
    if x==1:
        return False
    else:
        return True

# %%
prime(8)
# Out:
# False

# %%
prime(56963)
# Out:
# True

# %% [markdown]
# ## Alternative but slow for bigger numbers

# %%
def prime(x):
    check=[]
    lst=[1,x]
    for i in range(x):
        if x % (i+1) == 0:
            check.append(i+1)
    if check == lst:
        return True
    else:
        return False

# %%
prime(7)
# Out:
# True

# %%
prime(12)
# Out:
# False

# %%
prime(56963)
# Out:
# True

# %%
prime(56964)
# Out:
# False
